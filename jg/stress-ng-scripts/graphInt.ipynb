# %%
import tarfile
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Power Model - on Worker node [192.168.58.68]
#
# ## Experiment Setup
# ```
# ### Config: [TurboBoostOn.HyperThreadOn, TurboBoostOff.HyperThreadOff]
# ### Iterations: 3
# ### Number CPUs: TurboBoostOn.HyperThreadOn -> [1 - 32], TurboBoostOff.HyperThreadOff-> [1 - 16]
# ### Workload: stress-ng --cpu $i --cpu-method int64 -t 60s
# ```
#
# ## Experiment Run
# ```
# For each Iterations, and Config above, I ran stress-ng for 60 seconds each with a different number of CPUs increasing from 1 to 32 or 16, depending on the Config. As it is running, I collected the power measurement using this tool: https://github.com/handong32/rapl-service, which spills the per package CPU and DRAM power reading into a file. Figures below are the result of this experiment.
# ```

# %%
def plot(axs, combofig):
    # Plot data on each subplot
    for i, ax in enumerate(axs.flat):
        print(combofig[i])
    
        iter=combofig[i][0]
        tbht=combofig[i][1]
        ncpus=combofig[i][2]
        
        x = []
        ycpu = []
        ycpu_std = []
        ydram = []
        ydram_std = []
        for ncpu in range(1, ncpus+1):
            fname = f"stress-ng.iter{iter}.numcpus{ncpu}.{tbht}.int64.60"
            print(f"🟢 🟢 Reading {fname} 🟢 🟢")
            f=tar.extractfile(fname)
            content=f.read()
            decoded_content = content.decode("utf-8")
            cpupkgs=[]
            drampkgs=[]
            for line in decoded_content.split("\n"):
                if len(line) > 0:
                    ll = line.split(" ")
                    if float(ll[0]) > 0.0 and float(ll[1]) > 0.0:
                        cpupkgs.append(float(ll[0]))
                        drampkgs.append(float(ll[1]))
            print(np.mean(np.array(cpupkgs)), np.std(np.array(cpupkgs)))
            x.append(ncpu)
            ycpu.append(np.mean(np.array(cpupkgs)))
            ycpu_std.append(np.std(np.array(cpupkgs)))
            ydram.append(np.mean(np.array(drampkgs)))
            ydram_std.append(np.std(np.array(drampkgs)))
        ax.errorbar(x, ycpu, yerr=ycpu_std, fmt='x', capsize=1, label="CPU Package")
        ax.errorbar(x, ydram, yerr=ydram_std, fmt='o', capsize=1, label="DRAM Package")
        ax.set_xlabel('Number of CPUs')
        ax.set_ylabel('Mean Package Power (W)')
        ax.set_ylim(bottom=0, top=200)
        ax.set_title(f"Iteration [{iter+1}], {tbht}, \n stress-ng --cpu-method int64 -t 60s")
        ax.grid(True)
        ax.legend()
        #plt.show()
        
    # Adjust layout
    plt.tight_layout()
    
    # Show the plot
    plt.show()
    
tar = tarfile.open("/users/gustinj/results/stress-ng-results.tar.gz")

# %%
# Create a figure and subplots
fig, axs = plt.subplots(2, 3, figsize=(12, 6))

combofig = {0: [0, "TurboOn.HyperThreadOn", 32], 1: [1, "TurboOn.HyperThreadOn", 32], 2: [2, "TurboOn.HyperThreadOn", 32],
           3: [0, "TurboOff.HyperThreadOff", 16], 4: [1, "TurboOff.HyperThreadOff", 16], 5: [2, "TurboOff.HyperThreadOff", 16]}

plot(axs, combofig)
# Out:
# [0, 'TurboOn.HyperThreadOn', 32]
# 🟢 🟢 Reading stress-ng.iter0.numcpus1.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 37.16687012068965 1.9044402389818855
# 🟢 🟢 Reading stress-ng.iter0.numcpus2.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 41.91166318965517 2.7790186620148063
# 🟢 🟢 Reading stress-ng.iter0.numcpus3.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 53.60103643103449 4.669174613952491
# 🟢 🟢 Reading stress-ng.iter0.numcpus4.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 57.086492086206896 0.23387248296869131
# 🟢 🟢 Reading stress-ng.iter0.numcpus5.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 62.89411767241379 1.4601529479818485
# 🟢 🟢 Reading stress-ng.iter0.numcpus6.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 66.74593700000001 0.9219192536964247
# 🟢 🟢 Reading stress-ng.iter0.numcpus7.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 70.50622660344828 0.9681760315870179
# 🟢 🟢 Reading stress-ng.iter0.numcpus8.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 73.89777346551725 2.2805849643471254
# 🟢 🟢 Reading stress-ng.iter0.numcpus9.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 77.08660993103449 1.7657784411719828
# 🟢 🟢 Reading stress-ng.iter0.numcpus10.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 78.78687156896552 0.7990251663958194
# 🟢 🟢 Reading stress-ng.iter0.numcpus11.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 81.29744115517241 0.5418163915398231
# 🟢 🟢 Reading stress-ng.iter0.numcpus12.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 82.8423725 1.1050623100992099
# 🟢 🟢 Reading stress-ng.iter0.numcpus13.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 86.94567662068965 0.8044856444923278
# 🟢 🟢 Reading stress-ng.iter0.numcpus14.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 88.53428168965517 1.1593200171085616
# 🟢 🟢 Reading stress-ng.iter0.numcpus15.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 92.23720365517241 1.084654681751573
# 🟢 🟢 Reading stress-ng.iter0.numcpus16.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 95.35495731034483 0.8953952305886123
# 🟢 🟢 Reading stress-ng.iter0.numcpus17.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 95.44803277586207 1.1549432647503697
# 🟢 🟢 Reading stress-ng.iter0.numcpus18.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 95.8601084137931 0.6822872994617398
# 🟢 🟢 Reading stress-ng.iter0.numcpus19.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.1435304137931 1.151421189811996
# 🟢 🟢 Reading stress-ng.iter0.numcpus20.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.09082032758621 1.0923956941502055
# 🟢 🟢 Reading stress-ng.iter0.numcpus21.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.32634860344828 0.7513129335937683
# 🟢 🟢 Reading stress-ng.iter0.numcpus22.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.51281948275863 0.8223570863845824
# 🟢 🟢 Reading stress-ng.iter0.numcpus23.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.36012003448275 1.0376357126071043
# 🟢 🟢 Reading stress-ng.iter0.numcpus24.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.01706881034484 0.7376756923745874
# 🟢 🟢 Reading stress-ng.iter0.numcpus25.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.2893707586207 0.8882667244869277
# 🟢 🟢 Reading stress-ng.iter0.numcpus26.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.62988594827587 0.8806996505027335
# 🟢 🟢 Reading stress-ng.iter0.numcpus27.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.82465439655172 1.4453756085480165
# 🟢 🟢 Reading stress-ng.iter0.numcpus28.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.27519165517242 0.9679135582836556
# 🟢 🟢 Reading stress-ng.iter0.numcpus29.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.26537032758621 0.8548131688536388
# 🟢 🟢 Reading stress-ng.iter0.numcpus30.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.88289774137931 0.8705640929646697
# 🟢 🟢 Reading stress-ng.iter0.numcpus31.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 99.33255639655172 0.13374025469297832
# 🟢 🟢 Reading stress-ng.iter0.numcpus32.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 100.15488722413795 2.179260585570016
# [1, 'TurboOn.HyperThreadOn', 32]
# 🟢 🟢 Reading stress-ng.iter1.numcpus1.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 40.99898981034483 0.310869377148625
# 🟢 🟢 Reading stress-ng.iter1.numcpus2.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 48.17654837931035 1.3554329763720605
# 🟢 🟢 Reading stress-ng.iter1.numcpus3.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 54.694389551724136 4.448651480054754
# 🟢 🟢 Reading stress-ng.iter1.numcpus4.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 60.0141244137931 2.26553913197885
# 🟢 🟢 Reading stress-ng.iter1.numcpus5.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 65.48179891379311 0.2551750870075685
# 🟢 🟢 Reading stress-ng.iter1.numcpus6.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 67.0199332586207 1.2962104394840357
# 🟢 🟢 Reading stress-ng.iter1.numcpus7.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 71.18123232758622 1.3682331342479155
# 🟢 🟢 Reading stress-ng.iter1.numcpus8.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 73.7213155862069 1.1431464733880128
# 🟢 🟢 Reading stress-ng.iter1.numcpus9.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 77.71137001724139 1.1528887389684779
# 🟢 🟢 Reading stress-ng.iter1.numcpus10.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 80.26519668965517 1.3980709364400603
# 🟢 🟢 Reading stress-ng.iter1.numcpus11.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 83.32679481034484 1.7854482232476385
# 🟢 🟢 Reading stress-ng.iter1.numcpus12.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 84.99437532758621 0.5896303016286591
# 🟢 🟢 Reading stress-ng.iter1.numcpus13.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 86.8076719137931 0.5723039353518528
# 🟢 🟢 Reading stress-ng.iter1.numcpus14.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 89.25580043103449 0.5729131782418185
# 🟢 🟢 Reading stress-ng.iter1.numcpus15.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 92.15208065517241 2.2981854878697123
# 🟢 🟢 Reading stress-ng.iter1.numcpus16.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 95.44133996551723 1.3968812115311091
# 🟢 🟢 Reading stress-ng.iter1.numcpus17.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.13667141379311 0.869507664182518
# 🟢 🟢 Reading stress-ng.iter1.numcpus18.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 95.83093681034482 1.443132886539504
# 🟢 🟢 Reading stress-ng.iter1.numcpus19.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.22223108620689 0.8466436406638639
# 🟢 🟢 Reading stress-ng.iter1.numcpus20.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.58302463793103 1.025617041761045
# 🟢 🟢 Reading stress-ng.iter1.numcpus21.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.70843720689655 0.8928053250366041
# 🟢 🟢 Reading stress-ng.iter1.numcpus22.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.04929015517241 0.7669315426655131
# 🟢 🟢 Reading stress-ng.iter1.numcpus23.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.35818586206896 0.7337014030465188
# 🟢 🟢 Reading stress-ng.iter1.numcpus24.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.16897900000001 1.039300760552597
# 🟢 🟢 Reading stress-ng.iter1.numcpus25.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.50553636206895 0.8024962470915298
# 🟢 🟢 Reading stress-ng.iter1.numcpus26.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.7940863448276 0.6843253604364429
# 🟢 🟢 Reading stress-ng.iter1.numcpus27.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.60451739655173 1.0711208085051633
# 🟢 🟢 Reading stress-ng.iter1.numcpus28.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.97065787931034 0.9152994046004089
# 🟢 🟢 Reading stress-ng.iter1.numcpus29.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.2947790357143 1.2443669584611938
# 🟢 🟢 Reading stress-ng.iter1.numcpus30.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.94047810344827 1.0472919520270083
# 🟢 🟢 Reading stress-ng.iter1.numcpus31.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 99.89747986206896 1.2489934959967788
# 🟢 🟢 Reading stress-ng.iter1.numcpus32.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 100.56811106896551 0.021431948096291766
# [2, 'TurboOn.HyperThreadOn', 32]
# 🟢 🟢 Reading stress-ng.iter2.numcpus1.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 40.962706465517236 0.2855256039931667
# 🟢 🟢 Reading stress-ng.iter2.numcpus2.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 47.108695241379316 0.4577343629106112
# 🟢 🟢 Reading stress-ng.iter2.numcpus3.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 54.7308139137931 1.3914072562638145
# 🟢 🟢 Reading stress-ng.iter2.numcpus4.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 60.73261860344828 1.6266218829545436
# 🟢 🟢 Reading stress-ng.iter2.numcpus5.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 64.60535396551724 2.873854935248808
# 🟢 🟢 Reading stress-ng.iter2.numcpus6.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 69.50115859649124 0.4613109197419376
# 🟢 🟢 Reading stress-ng.iter2.numcpus7.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 72.35828374137931 0.4283654706437557
# 🟢 🟢 Reading stress-ng.iter2.numcpus8.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 74.28667693103448 1.5526253477583662
# 🟢 🟢 Reading stress-ng.iter2.numcpus9.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 77.84578415517242 1.3173061841680176
# 🟢 🟢 Reading stress-ng.iter2.numcpus10.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 79.98047512068965 1.4299293269590718
# 🟢 🟢 Reading stress-ng.iter2.numcpus11.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 83.39565715517242 1.5602532343579494
# 🟢 🟢 Reading stress-ng.iter2.numcpus12.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 85.2687735862069 1.5770567295396212
# 🟢 🟢 Reading stress-ng.iter2.numcpus13.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 86.25700531034484 0.7065766431321302
# 🟢 🟢 Reading stress-ng.iter2.numcpus14.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 89.14759560344828 0.5726191362686309
# 🟢 🟢 Reading stress-ng.iter2.numcpus15.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 92.8026480862069 0.7134191685764064
# 🟢 🟢 Reading stress-ng.iter2.numcpus16.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 95.76456744827586 1.331888606131147
# 🟢 🟢 Reading stress-ng.iter2.numcpus17.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.10107529310345 0.9886963509134054
# 🟢 🟢 Reading stress-ng.iter2.numcpus18.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.14283068965518 1.0232703683945494
# 🟢 🟢 Reading stress-ng.iter2.numcpus19.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.19207131034483 0.8492136202702211
# 🟢 🟢 Reading stress-ng.iter2.numcpus20.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.46268015517242 0.4485694491788083
# 🟢 🟢 Reading stress-ng.iter2.numcpus21.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.2726114137931 1.1219436917262122
# 🟢 🟢 Reading stress-ng.iter2.numcpus22.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.83260894827586 0.8735402172925593
# 🟢 🟢 Reading stress-ng.iter2.numcpus23.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 96.67836255172413 0.667659694370882
# 🟢 🟢 Reading stress-ng.iter2.numcpus24.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.36747477586206 0.6873657749003166
# 🟢 🟢 Reading stress-ng.iter2.numcpus25.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.49664413793104 0.8169056745819907
# 🟢 🟢 Reading stress-ng.iter2.numcpus26.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.86989201724137 1.2318310566277773
# 🟢 🟢 Reading stress-ng.iter2.numcpus27.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.1292861724138 0.83531383306718
# 🟢 🟢 Reading stress-ng.iter2.numcpus28.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 97.9615646724138 0.687649987353465
# 🟢 🟢 Reading stress-ng.iter2.numcpus29.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.58063942857143 0.8601277382205853
# 🟢 🟢 Reading stress-ng.iter2.numcpus30.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 98.9585024137931 0.9682877464209518
# 🟢 🟢 Reading stress-ng.iter2.numcpus31.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 99.88945905172413 1.20470374525586
# 🟢 🟢 Reading stress-ng.iter2.numcpus32.TurboOn.HyperThreadOn.int64.60 🟢 🟢
# 100.11314236206896 2.1547057993399057
# [0, 'TurboOff.HyperThreadOff', 16]
# 🟢 🟢 Reading stress-ng.iter0.numcpus1.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 37.93488286206896 1.8708072812565062
# 🟢 🟢 Reading stress-ng.iter0.numcpus2.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 42.62508736206897 2.8389268731901978
# 🟢 🟢 Reading stress-ng.iter0.numcpus3.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 46.285911810344835 0.5917612548837303
# 🟢 🟢 Reading stress-ng.iter0.numcpus4.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 49.65037060344827 1.5495647091953222
# 🟢 🟢 Reading stress-ng.iter0.numcpus5.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 52.39299696551724 1.4954805545178445
# 🟢 🟢 Reading stress-ng.iter0.numcpus6.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 57.59184953448276 0.37466982563954365
# 🟢 🟢 Reading stress-ng.iter0.numcpus7.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 59.7886299137931 0.11815629939345015
# 🟢 🟢 Reading stress-ng.iter0.numcpus8.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 62.7529444137931 0.6844971786941938
# 🟢 🟢 Reading stress-ng.iter0.numcpus9.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 66.05746256896552 0.815492389767259
# 🟢 🟢 Reading stress-ng.iter0.numcpus10.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 69.44422962068964 0.8234894322289664
# 🟢 🟢 Reading stress-ng.iter0.numcpus11.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 73.27689763793103 1.6393367495425966
# 🟢 🟢 Reading stress-ng.iter0.numcpus12.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 76.71426710344828 0.19041206650339385
# 🟢 🟢 Reading stress-ng.iter0.numcpus13.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 79.85678418965516 0.43798549881743915
# 🟢 🟢 Reading stress-ng.iter0.numcpus14.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 84.13293031034482 0.30500800422081675
# 🟢 🟢 Reading stress-ng.iter0.numcpus15.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 86.6518196724138 0.3178519426566392
# 🟢 🟢 Reading stress-ng.iter0.numcpus16.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 89.58998470689656 0.16595429470500217
# [1, 'TurboOff.HyperThreadOff', 16]
# 🟢 🟢 Reading stress-ng.iter1.numcpus1.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 38.31800051724138 1.1181088787656104
# 🟢 🟢 Reading stress-ng.iter1.numcpus2.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 43.257271603448274 1.5928934402422608
# 🟢 🟢 Reading stress-ng.iter1.numcpus3.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 46.3021725 1.2553566452116893
# 🟢 🟢 Reading stress-ng.iter1.numcpus4.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 49.84136751724138 1.8693618438922728
# 🟢 🟢 Reading stress-ng.iter1.numcpus5.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 53.26201439655173 1.4285419943398148
# 🟢 🟢 Reading stress-ng.iter1.numcpus6.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 56.38878337931035 0.44203671185320587
# 🟢 🟢 Reading stress-ng.iter1.numcpus7.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 59.128335896551725 1.3403900424094872
# 🟢 🟢 Reading stress-ng.iter1.numcpus8.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 62.71542358620689 0.9109329513641127
# 🟢 🟢 Reading stress-ng.iter1.numcpus9.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 66.36333596551724 1.5027318931370315
# 🟢 🟢 Reading stress-ng.iter1.numcpus10.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 70.20056151724138 0.10444880560487074
# 🟢 🟢 Reading stress-ng.iter1.numcpus11.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 73.92682939655172 0.5482060765566975
# 🟢 🟢 Reading stress-ng.iter1.numcpus12.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 77.03668634482759 0.2145130450691675
# 🟢 🟢 Reading stress-ng.iter1.numcpus13.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 80.22012429310345 0.6549338048095744
# 🟢 🟢 Reading stress-ng.iter1.numcpus14.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 83.10255598275863 0.135708647256755
# 🟢 🟢 Reading stress-ng.iter1.numcpus15.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 85.93990668965519 0.39472144863475284
# 🟢 🟢 Reading stress-ng.iter1.numcpus16.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 90.13246210344829 0.1256795206600266
# [2, 'TurboOff.HyperThreadOff', 16]
# 🟢 🟢 Reading stress-ng.iter2.numcpus1.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 38.60076162068966 2.195489079322236
# 🟢 🟢 Reading stress-ng.iter2.numcpus2.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 43.050698120689646 2.2007774997254956
# 🟢 🟢 Reading stress-ng.iter2.numcpus3.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 46.57211622413793 2.9025914698027444
# 🟢 🟢 Reading stress-ng.iter2.numcpus4.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 49.467806068965515 3.1389743658177744
# 🟢 🟢 Reading stress-ng.iter2.numcpus5.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 53.624784293103446 0.531448213536825
# 🟢 🟢 Reading stress-ng.iter2.numcpus6.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 56.546285637931035 1.6362160090536986
# 🟢 🟢 Reading stress-ng.iter2.numcpus7.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 59.37156937931035 1.0577255906255814
# 🟢 🟢 Reading stress-ng.iter2.numcpus8.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 62.843923655172425 0.14872306830453547
# 🟢 🟢 Reading stress-ng.iter2.numcpus9.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 66.65225213793104 0.580824516025411
# 🟢 🟢 Reading stress-ng.iter2.numcpus10.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 69.33006548275863 1.5840918622154287
# 🟢 🟢 Reading stress-ng.iter2.numcpus11.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 73.00650762068966 1.1468327312368778
# 🟢 🟢 Reading stress-ng.iter2.numcpus12.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 76.70684505172413 0.12947230462194598
# 🟢 🟢 Reading stress-ng.iter2.numcpus13.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 80.40412429310344 0.22659989102106606
# 🟢 🟢 Reading stress-ng.iter2.numcpus14.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 83.15495879310343 0.13770141066249006
# 🟢 🟢 Reading stress-ng.iter2.numcpus15.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 86.50970665517241 0.3196213961020543
# 🟢 🟢 Reading stress-ng.iter2.numcpus16.TurboOff.HyperThreadOff.int64.60 🟢 🟢
# 89.54381379310344 0.10808427861846712

# %% [markdown]
# # Analysis of figures above
# ```
# 1) Top 3 figures has TurboBoost and HyperThread ON, and bottom 3 figures has them disabled
# 2) The X-axis Mean Package Power (W), is averaged over a 60 second run of stress-ng with an increasing number of CPUs set. There is also standard deviation shown as y-error bars for each mean power measurement.
# 3) Overall, at maybe 15? CPUs we see the power plateau which probably means we are hitting the peak power that the node can support.
# 4) There is a difference in Power between the two Configs (see figures below), the slope with HyperThreading on is steeper - perhaps the CPU frequency is boosted to support the stress-ng workload, we don't measure performance of stress-ng so its hard to say what is the performance-power trade-off in this scenario
# ```
