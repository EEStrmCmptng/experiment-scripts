# %%
import tarfile
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Power Model - on Worker node [192.168.58.68]
#
# ## Experiment Setup
# ```
# ### Config: [TurboBoostOn.HyperThreadOn, TurboBoostOff.HyperThreadOff]
# ### Iterations: 3
# ### Number CPUs: TurboBoostOn.HyperThreadOn -> [1 - 32], TurboBoostOff.HyperThreadOff-> [1 - 16]
# ### Workload: stress-ng --matrix $i -t 60s
# ```
#
# ## Experiment Run
# ```
# For each Iterations, and Config above, I ran stress-ng for 60 seconds each with a different number of CPUs increasing from 1 to 32 or 16, depending on the Config. As it is running, I collected the power measurement using this tool: https://github.com/handong32/rapl-service, which spills the per package CPU and DRAM power reading into a file. Figures below are the result of this experiment.
# ```

# %%
def plot(axs, combofig):
    # Plot data on each subplot
    for i, ax in enumerate(axs.flat):
        print(combofig[i])
    
        iter=combofig[i][0]
        tbht=combofig[i][1]
        ncpus=combofig[i][2]
        
        x = []
        ycpu = []
        ycpu_std = []
        ydram = []
        ydram_std = []
        for ncpu in range(1, ncpus+1):
            fname = f"stress-ng.iter{iter}.numcpus{ncpu}.{tbht}.matrix.60"
            print(f"🟢 🟢 Reading {fname} 🟢 🟢")
            f=tar.extractfile(fname)
            content=f.read()
            decoded_content = content.decode("utf-8")
            cpupkgs=[]
            drampkgs=[]
            for line in decoded_content.split("\n"):
                if len(line) > 0:
                    ll = line.split(" ")
                    if float(ll[0]) > 0.0 and float(ll[1]) > 0.0:
                        cpupkgs.append(float(ll[0]))
                        drampkgs.append(float(ll[1]))
            print(np.mean(np.array(cpupkgs)), np.std(np.array(cpupkgs)))
            x.append(ncpu)
            ycpu.append(np.mean(np.array(cpupkgs)))
            ycpu_std.append(np.std(np.array(cpupkgs)))
            ydram.append(np.mean(np.array(drampkgs)))
            ydram_std.append(np.std(np.array(drampkgs)))
        ax.errorbar(x, ycpu, yerr=ycpu_std, fmt='x', capsize=1, label="CPU Package")
        ax.errorbar(x, ydram, yerr=ydram_std, fmt='o', capsize=1, label="DRAM Package")
        ax.set_xlabel('Matrix Instances')
        ax.set_ylabel('Mean Package Power (W)')
        ax.set_ylim(bottom=0, top=200)
        ax.set_title(f"Iteration [{iter+1}], {tbht}, \n stress-ng --matrix -t 60s")
        ax.grid(True)
        ax.legend()
        #plt.show()
        
    # Adjust layout
    plt.tight_layout()
    
    # Show the plot
    plt.show()
    
tar = tarfile.open("/users/gustinj/results/stress-ng-results.tar.gz")

# %%
# Create a figure and subplots
fig, axs = plt.subplots(2, 3, figsize=(12, 6))

combofig = {0: [0, "TurboOn.HyperThreadOn", 32], 1: [1, "TurboOn.HyperThreadOn", 32], 2: [2, "TurboOn.HyperThreadOn", 32],
           3: [0, "TurboOff.HyperThreadOff", 16], 4: [1, "TurboOff.HyperThreadOff", 16], 5: [2, "TurboOff.HyperThreadOff", 16]}

plot(axs, combofig)
# Out:
# [0, 'TurboOn.HyperThreadOn', 32]
# 🟢 🟢 Reading stress-ng.iter0.numcpus1.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 44.855769775862065 0.2785956468310454
# 🟢 🟢 Reading stress-ng.iter0.numcpus2.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 50.23953346551723 1.8953527161016779
# 🟢 🟢 Reading stress-ng.iter0.numcpus3.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 65.60773142857143 3.3122399324843124
# 🟢 🟢 Reading stress-ng.iter0.numcpus4.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 68.1959765862069 2.9953860071345306
# 🟢 🟢 Reading stress-ng.iter0.numcpus5.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 80.92659368965516 2.149805546077247
# 🟢 🟢 Reading stress-ng.iter0.numcpus6.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 90.2982093275862 2.2096117572611096
# 🟢 🟢 Reading stress-ng.iter0.numcpus7.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 94.69721198275862 3.1121373715796095
# 🟢 🟢 Reading stress-ng.iter0.numcpus8.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 100.14693170689655 2.935247365055228
# 🟢 🟢 Reading stress-ng.iter0.numcpus9.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 104.09346908620688 0.8599820648984955
# 🟢 🟢 Reading stress-ng.iter0.numcpus10.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 108.94578918965516 1.6862103677079792
# 🟢 🟢 Reading stress-ng.iter0.numcpus11.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 112.05123484482758 1.7191117749455604
# 🟢 🟢 Reading stress-ng.iter0.numcpus12.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 116.30811800000002 1.5758751527294401
# 🟢 🟢 Reading stress-ng.iter0.numcpus13.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 119.76587227586208 2.302490290688838
# 🟢 🟢 Reading stress-ng.iter0.numcpus14.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 122.69940401724136 1.521469580127367
# 🟢 🟢 Reading stress-ng.iter0.numcpus15.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 128.36197534482758 2.370096053337325
# 🟢 🟢 Reading stress-ng.iter0.numcpus16.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 133.74391434482757 1.587157091318349
# 🟢 🟢 Reading stress-ng.iter0.numcpus17.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 133.9533575689655 1.5968816484329824
# 🟢 🟢 Reading stress-ng.iter0.numcpus18.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 135.12048863793103 1.897467725786441
# 🟢 🟢 Reading stress-ng.iter0.numcpus19.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 135.63675144642858 1.9960856095467703
# 🟢 🟢 Reading stress-ng.iter0.numcpus20.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 136.32170579310343 2.3293985819293077
# 🟢 🟢 Reading stress-ng.iter0.numcpus21.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 137.40785060344828 1.4171035707706499
# 🟢 🟢 Reading stress-ng.iter0.numcpus22.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 138.35097953448278 1.4930624009921538
# 🟢 🟢 Reading stress-ng.iter0.numcpus23.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 139.84801624137933 1.380924486485765
# 🟢 🟢 Reading stress-ng.iter0.numcpus24.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 140.99491720689656 1.2844944962117189
# 🟢 🟢 Reading stress-ng.iter0.numcpus25.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 140.8491126896552 2.2444541154438786
# 🟢 🟢 Reading stress-ng.iter0.numcpus26.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 141.73993546551725 1.7393708864916544
# 🟢 🟢 Reading stress-ng.iter0.numcpus27.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 142.94428225862066 2.324627460949681
# 🟢 🟢 Reading stress-ng.iter0.numcpus28.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 143.1576138275862 1.6199591619058027
# 🟢 🟢 Reading stress-ng.iter0.numcpus29.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 144.64813648275864 1.7875612043609552
# 🟢 🟢 Reading stress-ng.iter0.numcpus30.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 146.78504263793104 0.6181806177880509
# 🟢 🟢 Reading stress-ng.iter0.numcpus31.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 147.91073394827586 1.9953399306885424
# 🟢 🟢 Reading stress-ng.iter0.numcpus32.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 148.58805063793102 3.317165130090705
# [1, 'TurboOn.HyperThreadOn', 32]
# 🟢 🟢 Reading stress-ng.iter1.numcpus1.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 44.94549034482758 0.4112929042326434
# 🟢 🟢 Reading stress-ng.iter1.numcpus2.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 57.23468780357143 1.38366434068983
# 🟢 🟢 Reading stress-ng.iter1.numcpus3.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 67.77583581034483 2.9541382081834273
# 🟢 🟢 Reading stress-ng.iter1.numcpus4.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 78.13690922413794 0.318147374978903
# 🟢 🟢 Reading stress-ng.iter1.numcpus5.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 82.22276567241381 2.434297962048369
# 🟢 🟢 Reading stress-ng.iter1.numcpus6.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 88.47504498275863 2.918388661805573
# 🟢 🟢 Reading stress-ng.iter1.numcpus7.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 93.38002908620689 2.1700025628922996
# 🟢 🟢 Reading stress-ng.iter1.numcpus8.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 98.95074148275863 3.8091446265838016
# 🟢 🟢 Reading stress-ng.iter1.numcpus9.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 103.49089729310346 3.284636032358548
# 🟢 🟢 Reading stress-ng.iter1.numcpus10.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 108.30652908620688 2.4528866709442942
# 🟢 🟢 Reading stress-ng.iter1.numcpus11.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 112.7597414310345 0.421962166107756
# 🟢 🟢 Reading stress-ng.iter1.numcpus12.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 117.34051303448277 1.9963566714486884
# 🟢 🟢 Reading stress-ng.iter1.numcpus13.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 120.28564877586207 1.4790475146544655
# 🟢 🟢 Reading stress-ng.iter1.numcpus14.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 123.61249517241379 1.47257964135673
# 🟢 🟢 Reading stress-ng.iter1.numcpus15.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 129.16040777586207 1.6179894299305642
# 🟢 🟢 Reading stress-ng.iter1.numcpus16.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 132.96624122413795 1.7814846398119457
# 🟢 🟢 Reading stress-ng.iter1.numcpus17.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 134.73015510344828 1.508497512430735
# 🟢 🟢 Reading stress-ng.iter1.numcpus18.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 135.52348386206896 1.1742679429987433
# 🟢 🟢 Reading stress-ng.iter1.numcpus19.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 136.0937678448276 1.2074307377081621
# 🟢 🟢 Reading stress-ng.iter1.numcpus20.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 137.19370665517243 1.0004843888204706
# 🟢 🟢 Reading stress-ng.iter1.numcpus21.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 137.5218863275862 1.612234016110955
# 🟢 🟢 Reading stress-ng.iter1.numcpus22.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 138.3656942241379 1.2820346558245628
# 🟢 🟢 Reading stress-ng.iter1.numcpus23.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 138.6393475172414 1.7122226453261258
# 🟢 🟢 Reading stress-ng.iter1.numcpus24.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 139.67049858620692 1.810936668122137
# 🟢 🟢 Reading stress-ng.iter1.numcpus25.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 140.62498313793103 1.2671225519047606
# 🟢 🟢 Reading stress-ng.iter1.numcpus26.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 141.63665241379312 1.5041850041824696
# 🟢 🟢 Reading stress-ng.iter1.numcpus27.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 142.54665613793102 1.6817177595630644
# 🟢 🟢 Reading stress-ng.iter1.numcpus28.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 143.1618830862069 1.5053849271614328
# 🟢 🟢 Reading stress-ng.iter1.numcpus29.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 144.24175079310345 1.9333519229226417
# 🟢 🟢 Reading stress-ng.iter1.numcpus30.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 145.65851139655175 1.98014073945799
# 🟢 🟢 Reading stress-ng.iter1.numcpus31.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 147.62509467241378 2.165525315968093
# 🟢 🟢 Reading stress-ng.iter1.numcpus32.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 149.2958563275862 0.2678097078590795
# [2, 'TurboOn.HyperThreadOn', 32]
# 🟢 🟢 Reading stress-ng.iter2.numcpus1.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 45.302633275862064 0.2816114226541041
# 🟢 🟢 Reading stress-ng.iter2.numcpus2.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 55.12421910344828 0.9786295623897189
# 🟢 🟢 Reading stress-ng.iter2.numcpus3.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 66.5474495862069 4.936973953289316
# 🟢 🟢 Reading stress-ng.iter2.numcpus4.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 76.60573601724138 2.6923530163247893
# 🟢 🟢 Reading stress-ng.iter2.numcpus5.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 83.73841491379311 3.1281353970262264
# 🟢 🟢 Reading stress-ng.iter2.numcpus6.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 89.3108373965517 0.7543819331050936
# 🟢 🟢 Reading stress-ng.iter2.numcpus7.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 94.77468979310345 2.691763061856733
# 🟢 🟢 Reading stress-ng.iter2.numcpus8.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 99.8539145 1.8824907800216886
# 🟢 🟢 Reading stress-ng.iter2.numcpus9.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 103.63469093103448 2.21887497543327
# 🟢 🟢 Reading stress-ng.iter2.numcpus10.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 108.82322644827586 3.133911818815023
# 🟢 🟢 Reading stress-ng.iter2.numcpus11.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 111.88495401724138 2.8200611342643973
# 🟢 🟢 Reading stress-ng.iter2.numcpus12.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 115.51234063793103 2.9784229701233436
# 🟢 🟢 Reading stress-ng.iter2.numcpus13.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 119.46987072413792 0.790459102072045
# 🟢 🟢 Reading stress-ng.iter2.numcpus14.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 122.6961596724138 1.5123441833291111
# 🟢 🟢 Reading stress-ng.iter2.numcpus15.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 127.5154492413793 2.623711480662238
# 🟢 🟢 Reading stress-ng.iter2.numcpus16.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 133.51761181034485 1.9467607323387432
# 🟢 🟢 Reading stress-ng.iter2.numcpus17.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 134.80135265517242 1.4583173351476644
# 🟢 🟢 Reading stress-ng.iter2.numcpus18.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 135.25295913793104 1.5965545235946585
# 🟢 🟢 Reading stress-ng.iter2.numcpus19.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 135.67072165517243 2.0373848325711514
# 🟢 🟢 Reading stress-ng.iter2.numcpus20.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 136.87594601724138 0.9414792534667776
# 🟢 🟢 Reading stress-ng.iter2.numcpus21.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 136.95839820689656 1.7725011222912448
# 🟢 🟢 Reading stress-ng.iter2.numcpus22.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 137.38628306896553 2.121747835565404
# 🟢 🟢 Reading stress-ng.iter2.numcpus23.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 137.9316795689655 1.590057144678152
# 🟢 🟢 Reading stress-ng.iter2.numcpus24.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 139.08856731034484 2.07590538067084
# 🟢 🟢 Reading stress-ng.iter2.numcpus25.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 139.99692822413795 2.2613970033774735
# 🟢 🟢 Reading stress-ng.iter2.numcpus26.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 141.26339822413794 2.3666022050177618
# 🟢 🟢 Reading stress-ng.iter2.numcpus27.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 141.91820027586206 1.4387391961488585
# 🟢 🟢 Reading stress-ng.iter2.numcpus28.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 142.6727643214286 1.7075500300469564
# 🟢 🟢 Reading stress-ng.iter2.numcpus29.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 144.22082413793103 1.6574656646861685
# 🟢 🟢 Reading stress-ng.iter2.numcpus30.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 145.88735018965517 2.086090883505875
# 🟢 🟢 Reading stress-ng.iter2.numcpus31.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 146.90380751724138 3.339767395258876
# 🟢 🟢 Reading stress-ng.iter2.numcpus32.TurboOn.HyperThreadOn.matrix.60 🟢 🟢
# 148.7620460689655 3.401895517646575
# [0, 'TurboOff.HyperThreadOff', 16]
# 🟢 🟢 Reading stress-ng.iter0.numcpus1.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 39.64197406896551 2.3549346435005143
# 🟢 🟢 Reading stress-ng.iter0.numcpus2.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 47.386574620689665 3.0351319061449415
# 🟢 🟢 Reading stress-ng.iter0.numcpus3.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 51.89075439655173 3.342055227969439
# 🟢 🟢 Reading stress-ng.iter0.numcpus4.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 58.01003187931035 1.679494896378322
# 🟢 🟢 Reading stress-ng.iter0.numcpus5.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 63.70201472413793 1.346041222024099
# 🟢 🟢 Reading stress-ng.iter0.numcpus6.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 69.12064334482758 0.3226395131410303
# 🟢 🟢 Reading stress-ng.iter0.numcpus7.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 74.18378005172414 0.44705340439464447
# 🟢 🟢 Reading stress-ng.iter0.numcpus8.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 80.49267787931032 0.9939664251910824
# 🟢 🟢 Reading stress-ng.iter0.numcpus9.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 85.59732268965517 0.9791177756737174
# 🟢 🟢 Reading stress-ng.iter0.numcpus10.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 90.17074793103448 0.36700236590752244
# 🟢 🟢 Reading stress-ng.iter0.numcpus11.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 95.41953041379311 1.8267860399414022
# 🟢 🟢 Reading stress-ng.iter0.numcpus12.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 101.51647631034484 1.3964498862002641
# 🟢 🟢 Reading stress-ng.iter0.numcpus13.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 107.29334692857142 0.32192837418099096
# 🟢 🟢 Reading stress-ng.iter0.numcpus14.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 113.07012206896553 0.6033624435442767
# 🟢 🟢 Reading stress-ng.iter0.numcpus15.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 117.57982243103446 0.45494757867496144
# 🟢 🟢 Reading stress-ng.iter0.numcpus16.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 122.51477053448274 1.3033001863733593
# [1, 'TurboOff.HyperThreadOff', 16]
# 🟢 🟢 Reading stress-ng.iter1.numcpus1.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 40.43799036206896 0.6332970265035447
# 🟢 🟢 Reading stress-ng.iter1.numcpus2.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 47.13029112068966 1.9004844469393363
# 🟢 🟢 Reading stress-ng.iter1.numcpus3.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 52.719603465517245 1.849642999721169
# 🟢 🟢 Reading stress-ng.iter1.numcpus4.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 58.80508215517241 1.3748930821122534
# 🟢 🟢 Reading stress-ng.iter1.numcpus5.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 63.01055805172414 1.6365045677560646
# 🟢 🟢 Reading stress-ng.iter1.numcpus6.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 69.22535760344827 1.7691681406384479
# 🟢 🟢 Reading stress-ng.iter1.numcpus7.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 74.22279194827586 1.6873270899659558
# 🟢 🟢 Reading stress-ng.iter1.numcpus8.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 79.19627329310345 1.3848541541844264
# 🟢 🟢 Reading stress-ng.iter1.numcpus9.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 85.4159040862069 0.46636038888778014
# 🟢 🟢 Reading stress-ng.iter1.numcpus10.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 90.93209205172413 0.5294315286804758
# 🟢 🟢 Reading stress-ng.iter1.numcpus11.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 95.81996415517243 1.7719452970114784
# 🟢 🟢 Reading stress-ng.iter1.numcpus12.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 100.96946460344827 0.7732184232729605
# 🟢 🟢 Reading stress-ng.iter1.numcpus13.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 106.30971651724137 2.0851473166493153
# 🟢 🟢 Reading stress-ng.iter1.numcpus14.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 111.01845894827586 1.7776154928707584
# 🟢 🟢 Reading stress-ng.iter1.numcpus15.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 117.36067777586207 0.31098212587476504
# 🟢 🟢 Reading stress-ng.iter1.numcpus16.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 122.89628334482757 0.14008114403279337
# [2, 'TurboOff.HyperThreadOff', 16]
# 🟢 🟢 Reading stress-ng.iter2.numcpus1.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 40.589136568965515 1.1023698197888558
# 🟢 🟢 Reading stress-ng.iter2.numcpus2.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 46.42738815517242 3.031243391296417
# 🟢 🟢 Reading stress-ng.iter2.numcpus3.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 52.83348027586207 1.6363189819547324
# 🟢 🟢 Reading stress-ng.iter2.numcpus4.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 58.35282743103448 1.6219788668939634
# 🟢 🟢 Reading stress-ng.iter2.numcpus5.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 63.400496879310346 0.32905654035633264
# 🟢 🟢 Reading stress-ng.iter2.numcpus6.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 70.09603994827586 0.337371736656673
# 🟢 🟢 Reading stress-ng.iter2.numcpus7.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 74.3080718275862 0.40236739597627513
# 🟢 🟢 Reading stress-ng.iter2.numcpus8.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 78.34712903448276 1.6509763102886874
# 🟢 🟢 Reading stress-ng.iter2.numcpus9.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 84.4574775 0.9019677385765364
# 🟢 🟢 Reading stress-ng.iter2.numcpus10.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 90.42589903448275 1.0564065464420669
# 🟢 🟢 Reading stress-ng.iter2.numcpus11.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 95.16608606896551 1.7451297978850075
# 🟢 🟢 Reading stress-ng.iter2.numcpus12.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 101.00204468965516 0.15152535492681268
# 🟢 🟢 Reading stress-ng.iter2.numcpus13.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 105.69077174137931 0.32544497866807026
# 🟢 🟢 Reading stress-ng.iter2.numcpus14.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 111.03542137931035 0.5781061843088152
# 🟢 🟢 Reading stress-ng.iter2.numcpus15.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 116.30439389655172 0.6479611279022067
# 🟢 🟢 Reading stress-ng.iter2.numcpus16.TurboOff.HyperThreadOff.matrix.60 🟢 🟢
# 121.83182081034484 0.34521478557046825

# %% [markdown]
# # Analysis of figures above
# ```
# 1) Top 3 figures has TurboBoost and HyperThread ON, and bottom 3 figures has them disabled
# 2) The X-axis Mean Package Power (W), is averaged over a 60 second run of stress-ng with an increasing number of CPUs set. There is also standard deviation shown as y-error bars for each mean power measurement.
# 3) Overall, at maybe 15? CPUs we see the slope of the power decrease which probably means we are hitting the peak power that the node can support.
# 4) There is a difference in Power between the two Configs (see figures below), the slope with TurboBoost and HyperThreading on is steeper - perhaps the CPU frequency is boosted to support the stress-ng workload, we don't measure performance of stress-ng so its hard to say what is the performance-power trade-off in this scenario
# ```
